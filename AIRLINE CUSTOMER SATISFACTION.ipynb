# %%
import pandas as pd

# %%
d=pd.read_csv(r"C:\Users\OM ENTERPRISE\Desktop\ML DATA\ML Project - Decision Tree Airline Customer Satisfaction U16955468980.csv")

# %%
d
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0                0           0   70172    Male     Loyal Customer   13
# 1                1           1    5047    Male  disloyal Customer   25
# 2                2           2  110028  Female     Loyal Customer   26
# 3                3           3   24026  Female     Loyal Customer   25
# 4                4           4  119299    Male     Loyal Customer   61
# ...            ...         ...     ...     ...                ...  ...
# 9995          9995        9995  124365    Male     Loyal Customer   50
# 9996          9996        9996   22044    Male     Loyal Customer   38
# 9997          9997        9997   14057  Female     Loyal Customer   39
# 9998          9998        9998  113848    Male     Loyal Customer   52
# 9999          9999        9999    1865  Female     Loyal Customer   41
#
#        Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# ...

# %%
d=d.drop(["Unnamed: 0.1","Unnamed: 0","id"],axis=1)

# %%
d.columns=[ 'Gender', 'Customer Type', 'Age', 'Type of Travel',
       'Class', 'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
       'satisfaction']

# %%
d.isnull().sum()
# Out:
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             26
# satisfaction                          0
# dtype: int64

# %%
d=d.dropna()

# %%
d
# Out:
#       Gender      Customer Type  Age   Type of Travel     Class  \
# 0       Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1       Male  disloyal Customer   25  Business travel  Business
# 2     Female     Loyal Customer   26  Business travel  Business
# 3     Female     Loyal Customer   25  Business travel  Business
# 4       Male     Loyal Customer   61  Business travel  Business
# ...      ...                ...  ...              ...       ...
# 9995    Male     Loyal Customer   50  Business travel  Business
# 9996    Male     Loyal Customer   38  Business travel  Business
# 9997  Female     Loyal Customer   39  Business travel  Business
# 9998    Male     Loyal Customer   52  Business travel  Business
# 9999  Female     Loyal Customer   41  Business travel  Business
#
#       Flight Distance  Inflight wifi service  \
# 0                 460                      3
# 1                 235                      3
# 2                1142                      2
# ...

# %%
d
# Out:
#       Gender      Customer Type  Age   Type of Travel     Class  \
# 0       Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1       Male  disloyal Customer   25  Business travel  Business
# 2     Female     Loyal Customer   26  Business travel  Business
# 3     Female     Loyal Customer   25  Business travel  Business
# 4       Male     Loyal Customer   61  Business travel  Business
# ...      ...                ...  ...              ...       ...
# 9995    Male     Loyal Customer   50  Business travel  Business
# 9996    Male     Loyal Customer   38  Business travel  Business
# 9997  Female     Loyal Customer   39  Business travel  Business
# 9998    Male     Loyal Customer   52  Business travel  Business
# 9999  Female     Loyal Customer   41  Business travel  Business
#
#       Flight Distance  Inflight wifi service  \
# 0                 460                      3
# 1                 235                      3
# 2                1142                      2
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9974 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             9974 non-null   object
#  1   Customer Type                      9974 non-null   object
#  2   Age                                9974 non-null   int64
#  3   Type of Travel                     9974 non-null   object
#  4   Class                              9974 non-null   object
#  5   Flight Distance                    9974 non-null   int64
#  6   Inflight wifi service              9974 non-null   int64
#  7   Departure/Arrival time convenient  9974 non-null   int64
#  8   Ease of Online booking             9974 non-null   int64
#  9   Gate location                      9974 non-null   int64
#  10  Food and drink                     9974 non-null   int64
# ...

# %%
d.columns=[each.replace(" ","_")for each in d.columns]

# %%
d.columns
# Out:
# Index(['Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
d.head()
# Out:
#    Gender      Customer_Type  Age   Type_of_Travel     Class  Flight_Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# ...

# %%
d["Gender"]=d["Gender"].replace(["Male","Female"],[0,1])

# %%
d
# Out:
#       Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0          0     Loyal Customer   13  Personal Travel  Eco Plus
# 1          0  disloyal Customer   25  Business travel  Business
# 2          1     Loyal Customer   26  Business travel  Business
# 3          1     Loyal Customer   25  Business travel  Business
# 4          0     Loyal Customer   61  Business travel  Business
# ...      ...                ...  ...              ...       ...
# 9995       0     Loyal Customer   50  Business travel  Business
# 9996       0     Loyal Customer   38  Business travel  Business
# 9997       1     Loyal Customer   39  Business travel  Business
# 9998       0     Loyal Customer   52  Business travel  Business
# 9999       1     Loyal Customer   41  Business travel  Business
#
#       Flight_Distance  Inflight_wifi_service  \
# 0                 460                      3
# 1                 235                      3
# 2                1142                      2
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
nach=["Customer_type","Customer_type","Class","satisfaction"]

# %%
d[["Customer_Type","Type_of_Travel","Class","satisfaction"]]=d[["Customer_Type","Type_of_Travel","Class","satisfaction"]].apply(enc.fit_transform)

# %%
d.head()
# Out:
#    Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0       0              0   13               1      2              460
# 1       0              1   25               0      0              235
# 2       1              0   26               0      0             1142
# 3       1              0   25               0      0              562
# 4       0              0   61               0      0              214
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9974 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             9974 non-null   int64
#  1   Customer_Type                      9974 non-null   int32
#  2   Age                                9974 non-null   int64
#  3   Type_of_Travel                     9974 non-null   int32
#  4   Class                              9974 non-null   int32
#  5   Flight_Distance                    9974 non-null   int64
#  6   Inflight_wifi_service              9974 non-null   int64
#  7   Departure/Arrival_time_convenient  9974 non-null   int64
#  8   Ease_of_Online_booking             9974 non-null   int64
#  9   Gate_location                      9974 non-null   int64
#  10  Food_and_drink                     9974 non-null   int64
# ...

# %%
d["satisfaction"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='satisfaction'>

# %%
d["Gender"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
d[["Gender","satisfaction"]].groupby(["Gender"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Gender  satisfaction
# 0       0      0.438294
# 1       1      0.424451

# %%
d[["Age","satisfaction"]].groupby(["Age"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#     Age  satisfaction
# 71   79      0.666667
# 39   46      0.643192
# 34   41      0.632743
# 38   45      0.608466
# 66   73      0.600000
# ..  ...           ...
# 7    14      0.076923
# 0     7      0.071429
# 59   66      0.050000
# 69   76      0.000000
# 73   85      0.000000
#
# [74 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x=d.drop("satisfaction",axis=1)
y=d["satisfaction"]

# %%
x.shape
# Out:
# (9974, 22)

# %%
x_scaler=scaler.fit_transform(x)

# %%
x.shape
# Out:
# (9974, 22)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.6,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(max_depth=12,max_features="sqrt",min_samples_leaf=1,min_samples_split=2,criterion='gini')

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=12, max_features='sqrt')

# %%
model.score(x_train,y_train)
# Out:
# 0.9700868983957219

# %%
model.score(x_test,y_test)
# Out:
# 0.8852130325814537

# %%
pred_y=model.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,pred_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90      2257
#            1       0.87      0.86      0.87      1733
#
#     accuracy                           0.89      3990
#    macro avg       0.88      0.88      0.88      3990
# weighted avg       0.89      0.89      0.89      3990

# %%
confusion_matrix(y_test,pred_y)
# Out:
# array([[2040,  217],
#        [ 241, 1492]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(confusion_matrix(y_test,pred_y),annot=True,fmt='d')
# Out:
# <Axes: >

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
accuracy_score(y_test,pred_y)
# Out:
# 0.8852130325814537

# %%
recall_score(y_test,pred_y)
# Out:
# 0.860934795152914

# %%
precision_score(y_test,pred_y)
# Out:
# 0.8730251609128145
